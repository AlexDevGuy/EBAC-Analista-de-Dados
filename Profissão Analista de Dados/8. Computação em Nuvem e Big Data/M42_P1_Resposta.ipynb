# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Pipeline de Dados do Telegram I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Contexto;</li>
#   <li>Telegram;</li>
#   <li>Dados.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Telegram.

# %% [markdown]
# Replique as atividades da aula 2.

# %% [markdown]
# 1.1. Crie uma conta no **Telegram** caso não possua uma e faça o login na versão web da ferramenta através desse [link](https://web.telegram.org).

# %% [markdown]
# 1.2. Crie um *bot*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.3. Crie um grupo e adicione o *bot*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.4. Torne o *bot* administrador do grupo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.5. Desabilite a opção de adicionar o *bot* a novos grupos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.6. Envie diversos tipos de mensagens no grupo (text, imagem, arquivos, video, áudio, etc.) e as consuma utilizand a API de *bots* do **Telegram**.

# %% [markdown]
# > **Nota:** A documentação completa da API pode ser encontrada neste [link](https://core.telegram.org/bots/api)

# %%
from getpass import getpass

print('Insira o token:')
token = getpass()
# Out:
# Insira o token:
# ··········

# %%
# A url base é comum a todos os métodos da API.
import json
import requests

base_url = f'https://api.telegram.org/bot{token}'

# %%
# O método getMe retorna informações sobre o bot.
response = requests.get(url=f'{base_url}/getMe')
print(f'{base_url}/getMe')

print(json.dumps(json.loads(response.text), indent=2))
# Out:
# https://api.telegram.org/bot6926807717:AAEegjvAT9yHrfdoz_pSkadwxJuB0dUgdt8/getMe
# {
#   "ok": true,
#   "result": {
#     "id": 6926807717,
#     "is_bot": true,
#     "first_name": "monitor_bot",
#     "username": "monitor9000_bot",
#     "can_join_groups": false,
#     "can_read_all_group_messages": false,
#     "supports_inline_queries": false,
#     "can_connect_to_business": false
#   }
# }

# %%
# O método getMe retorna as mensagens captadas pelo bot.
response = requests.get(url=f'{base_url}/getUpdates')

print(json.dumps(json.loads(response.text), indent=2))
# Out:
# {
#   "ok": true,
#   "result": [
#     {
#       "update_id": 222678502,
#       "message": {
#         "message_id": 3,
#         "from": {
#           "id": 5246816719,
#           "is_bot": false,
#           "first_name": "Nie",
#           "username": "NieZzzv",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002189999845,
#           "title": "Chat_monitor_bot",
#           "type": "supergroup"
#         },
#         "date": 1720222381,
#         "text": "Hello world!"
#       }
#     },
#     {
#       "update_id": 222678503,
#       "message": {
#         "message_id": 4,
#         "from": {
#           "id": 5246816719,
#           "is_bot": false,
#           "first_name": "Nie",
#           "username": "NieZzzv",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002189999845,
#           "title": "Chat_monitor_bot",
#           "type": "supergroup"
#         },
#         "date": 1720222448,
#         "photo": [
#           {
#             "file_id": "AgACAgEAAyEFAASCiL7lAAMEZoiC8Loer2g_6aHPS6vZiKlhm0cAAgetMRsuUEFE3z0IQtv7JO0BAAMCAANzAAM1BA",
#             "file_unique_id": "AQADB60xGy5QQUR4",
#             "file_size": 1239,
#             "width": 90,
#             "height": 60
#           },
#           {
#             "file_id": "AgACAgEAAyEFAASCiL7lAAMEZoiC8Loer2g_6aHPS6vZiKlhm0cAAgetMRsuUEFE3z0IQtv7JO0BAAMCAANtAAM1BA",
#             "file_unique_id": "AQADB60xGy5QQURy",
#             "file_size": 13496,
#             "width": 320,
#             "height": 213
#           },
#           {
#             "file_id": "AgACAgEAAyEFAASCiL7lAAMEZoiC8Loer2g_6aHPS6vZiKlhm0cAAgetMRsuUEFE3z0IQtv7JO0BAAMCAAN4AAM1BA",
#             "file_unique_id": "AQADB60xGy5QQUR9",
#             "file_size": 53122,
#             "width": 800,
#             "height": 532
#           },
#           {
#             "file_id": "AgACAgEAAyEFAASCiL7lAAMEZoiC8Loer2g_6aHPS6vZiKlhm0cAAgetMRsuUEFE3z0IQtv7JO0BAAMCAAN5AAM1BA",
#             "file_unique_id": "AQADB60xGy5QQUR-",
#             "file_size": 67803,
#             "width": 1020,
#             "height": 678
#           }
#         ]
#       }
#     }
#   ]
# }
